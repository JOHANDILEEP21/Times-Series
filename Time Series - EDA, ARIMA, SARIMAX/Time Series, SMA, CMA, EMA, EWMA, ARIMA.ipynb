# %% [markdown]
# # Time Series:
#
# ### Simple Moving Average (SMA)
#
# ### Cumulative Moving Average (CMA)
#
# ### Exponential Moving Average (EMA)
#
# ### Exponential Weighted Moving Average (EWMA)
#
# ### Auto Regressive + Integrated + Moving Average (ARIMA)

# %%
import pandas_datareader.data as pdr
import pandas as pd
from datetime import datetime 
import matplotlib.pyplot as plt
# %matplotlib inline

import yfinance as yf

# %%
start_date = datetime(2017, 2, 27)
end_date = datetime(2024, 8, 14)

df = pdr.DataReader('TSLA', 'stooq', start_date, end_date)

# %%
df
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2024-08-14  207.3900  208.4400  198.7500  201.3800   70250014
# 2024-08-13  198.4700  208.4900  197.0600  207.8300   76247387
# 2024-08-12  199.0200  199.2600  194.6700  197.4900   64044903
# 2024-08-09  197.0500  200.8800  195.1100  200.0000   58648274
# 2024-08-08  195.7000  200.7000  192.0400  198.8400   65033874
# ...              ...       ...       ...       ...        ...
# 2017-03-03   16.7160   16.7933   16.6000   16.7713   43617600
# 2017-03-02   16.6473   16.8853   16.5513   16.6987   49825665
# 2017-03-01   16.9453   16.9900   16.6073   16.6680   71692410
# 2017-02-28   16.2793   16.7333   16.2600   16.6660   89202630
# 2017-02-27   16.5447   16.5573   16.1340   16.4153  168195495
#
# [1879 rows x 5 columns]

# %%
# start_date = datetime(2017, 2, 27)
# end_date = datetime(2024, 8, 22)

# df = yf.download('SBIN', start= start_date, end= end_date)

# %% [markdown]
# ### Simple Moving Average

# %%
df[df.index < datetime(2022,2,24)]['Open'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df1 = df[df.index < datetime(2022,2,26)]

# %%
df1 = df1.sort_index()

# %%
df1['Open:10 days rolling'] = df1['Open'].rolling(window=10, min_periods=1).mean()

# %%
df1.head(15)
# Out:
#                Open     High      Low    Close     Volume  \
# Date
# 2017-02-27  16.5447  16.5573  16.1340  16.4153  168195495
# 2017-02-28  16.2793  16.7333  16.2600  16.6660   89202630
# 2017-03-01  16.9453  16.9900  16.6073  16.6680   71692410
# 2017-03-02  16.6473  16.8853  16.5513  16.6987   49825665
# 2017-03-03  16.7160  16.7933  16.6000  16.7713   43617600
# 2017-03-06  16.5273  16.7800  16.5007  16.7473   49308435
# 2017-03-07  16.7947  16.9260  16.5547  16.5727   50127600
# 2017-03-08  16.4667  16.6713  16.3547  16.4553   54655065
# 2017-03-09  16.5087  16.5773  16.2000  16.3267   57780780
# 2017-03-10  16.4140  16.4333  16.2000  16.2460   45145755
# 2017-03-13  16.2927  16.4567  16.1853  16.4113   45339375
# 2017-03-14  16.4073  17.2080  16.4013  17.2000  113976690
# 2017-03-15  17.1333  17.4000  16.9513  17.0487   79962090
# 2017-03-16  17.4933  17.7167  17.2707  17.4700  106982295
# 2017-03-17  17.6000  17.6887  17.4133  17.4333   88687155
#
# ...

# %%
df1[['Open', 'Open:10 days rolling']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df1['Open:30 days rolling'] = df1['Open'].rolling(window=30, min_periods=1).mean()
df1['Open:50 days rolling'] = df1['Open'].rolling(window=50, min_periods=1).mean()

# %%
df1[['Open', 'Open:10 days rolling', 'Open:30 days rolling', 'Open:50 days rolling']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Expanding - Cumulative Moving Average (CMA)

# %%
df1['Open'].expanding().mean()
# Out:
# Date
# 2017-02-27    16.544700
# 2017-02-28    16.412000
# 2017-03-01    16.589767
# 2017-03-02    16.604150
# 2017-03-03    16.626520
#                 ...
# 2022-02-18    91.922118
# 2022-02-22    92.070185
# 2022-02-23    92.217037
# 2022-02-24    92.329226
# 2022-02-25    92.470031
# Name: Open, Length: 1260, dtype: float64

# %%
df1['Open'].expanding().mean().plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Exponential Moving Average (EMA)
#
# ### Lets smoothing factor - 0.1

# %%
df1['EMA_0.1'] = df1['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df1[['Open', 'EMA_0.1']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(15, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
df1['EMA_0.3'] = df1['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df1.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Open:10 days rolling',
#        'Open:30 days rolling', 'Open:50 days rolling', 'EMA_0.1', 'EMA_0.3'],
#       dtype='object')

# %%
df1[['Open', 'EMA_0.1', 'EMA_0.3']].plot(xlim=['2020-01-01', '2021-01-01'], figsize=(15, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Exponential Weighted Moving Average (EWMA)
#
# we can achieve this by using span in df.ewm(span=no_of_days)

# %%
df1['EMA_5days'] = df1['Open'].ewm(span=5).mean()

# %%
df1[['Open', 'EMA_0.1', 'EMA_5days']].plot(figsize=(15, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
8.0+(0.5)*(-2.0)
# Out:
# 7.0

# %%
10+(0.5)*(-2.0)
# Out:
# 9.0

# %%
9.0+(0.5)*(1.0)
# Out:
# 9.5

# %%
10.5+(0.5)*(-1.0)
# Out:
# 10.0
